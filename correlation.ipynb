# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = sns.load_dataset('titanic')
df2 = sns.load_dataset('iris')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
np.cov(df['age'],df['fare'])
# Out:
# array([[          nan,           nan],
#        [          nan, 2469.43684574]])

# %%
df.corr()  # Simple correlation
# Out:
# C:\Users\Waqar Haider\AppData\Local\Temp\ipykernel_17948\2886420612.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()  # Simple correlation
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
#Pearson correlation ( for normal data)
corr1 = df.corr(method='pearson')
corr1
# Out:
# C:\Users\Waqar Haider\AppData\Local\Temp\ipykernel_17948\3029537436.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr1 = df.corr(method='pearson')
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
#Spearman correlation (For non-normal data)
corr2 = df.corr(method='spearman')
corr2
# Out:
# C:\Users\Waqar Haider\AppData\Local\Temp\ipykernel_17948\1948295572.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr2 = df.corr(method='spearman')
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.339668 -0.052565  0.088879  0.138266  0.323736
# pclass     -0.339668  1.000000 -0.361666 -0.043019 -0.022801 -0.688032
# age        -0.052565 -0.361666  1.000000 -0.182061 -0.254212  0.135051
# sibsp       0.088879 -0.043019 -0.182061  1.000000  0.450014  0.447113
# parch       0.138266 -0.022801 -0.254212  0.450014  1.000000  0.410074
# fare        0.323736 -0.688032  0.135051  0.447113  0.410074  1.000000
# adult_male -0.557080  0.099351  0.257641 -0.307948 -0.397286 -0.308894
# alone      -0.203367  0.135896  0.167293 -0.828215 -0.683719 -0.531472
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.099351  0.135896
# age           0.257641  0.167293
# sibsp        -0.307948 -0.828215
# parch        -0.397286 -0.683719
# fare         -0.308894 -0.531472
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.heatmap(corr1, annot=True)
# Out:
# <AxesSubplot: >

# %%
corr1.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6be19_row0_col0, #T_6be19_row1_col1, #T_6be19_row2_col2, #T_6be19_row3_col3, #T_6be19_row4_col4, #T_6be19_row5_col5, #T_6be19_row6_col6, #T_6be19_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6be19_row0_col1, #T_6be19_row4_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6be19_row0_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6be19_row0_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6be19_row0_col4, #T_6be19_row1_col3, #T_6be19_row1_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_6be19_row0_col5, #T_6be19_row5_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_6be19_row0_col6, #T_6be19_row1_col2, #T_6be19_row1_col5, #T_6be19_row3_col7, #T_6be19_row4_col7, #T_6be19_row5_col1, #T_6be19_row6_col0, #T_6be19_row7_col3, #T_6be19_row7_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6be19_row0_col7, #T_6be19_row5_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6be19_row1_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6be19_row1_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_6be19_row1_col7 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_6be19_row2_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_6be19_row2_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6be19_row2_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6be19_row2_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_6be19_row2_col5, #T_6be19_row6_col1, #T_6be19_row7_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_6be19_row2_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_6be19_row2_col7, #T_6be19_row4_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_6be19_row3_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6be19_row3_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_6be19_row3_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6be19_row3_col4, #T_6be19_row4_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_6be19_row3_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_6be19_row3_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6be19_row4_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_6be19_row4_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_6be19_row4_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6be19_row5_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6be19_row5_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_6be19_row5_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_6be19_row5_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_6be19_row6_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_6be19_row6_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6be19_row6_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6be19_row6_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6be19_row6_col7 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_6be19_row7_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_6be19_row7_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_6be19_row7_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6be19_row7_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# </style>
# <table id="T_6be19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6be19_level0_col0" class="col_heading level0 col0" >survived</th>
#       <th id="T_6be19_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_6be19_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_6be19_level0_col3" class="col_heading level0 col3" >sibsp</th>
#       <th id="T_6be19_level0_col4" class="col_heading level0 col4" >parch</th>
#       <th id="T_6be19_level0_col5" class="col_heading level0 col5" >fare</th>
#       <th id="T_6be19_level0_col6" class="col_heading level0 col6" >adult_male</th>
#       <th id="T_6be19_level0_col7" class="col_heading level0 col7" >alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6be19_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_6be19_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6be19_row0_col1" class="data row0 col1" >-0.338481</td>
#       <td id="T_6be19_row0_col2" class="data row0 col2" >-0.077221</td>
#       <td id="T_6be19_row0_col3" class="data row0 col3" >-0.035322</td>
#       <td id="T_6be19_row0_col4" class="data row0 col4" >0.081629</td>
#       <td id="T_6be19_row0_col5" class="data row0 col5" >0.257307</td>
#       <td id="T_6be19_row0_col6" class="data row0 col6" >-0.557080</td>
#       <td id="T_6be19_row0_col7" class="data row0 col7" >-0.203367</td>
#     </tr>
#     <tr>
#       <th id="T_6be19_level0_row1" class="row_heading level0 row1" >pclass</th>
#       <td id="T_6be19_row1_col0" class="data row1 col0" >-0.338481</td>
#       <td id="T_6be19_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6be19_row1_col2" class="data row1 col2" >-0.369226</td>
#       <td id="T_6be19_row1_col3" class="data row1 col3" >0.083081</td>
#       <td id="T_6be19_row1_col4" class="data row1 col4" >0.018443</td>
#       <td id="T_6be19_row1_col5" class="data row1 col5" >-0.549500</td>
#       <td id="T_6be19_row1_col6" class="data row1 col6" >0.094035</td>
#       <td id="T_6be19_row1_col7" class="data row1 col7" >0.135207</td>
#     </tr>
#     <tr>
#       <th id="T_6be19_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_6be19_row2_col0" class="data row2 col0" >-0.077221</td>
#       <td id="T_6be19_row2_col1" class="data row2 col1" >-0.369226</td>
#       <td id="T_6be19_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6be19_row2_col3" class="data row2 col3" >-0.308247</td>
#       <td id="T_6be19_row2_col4" class="data row2 col4" >-0.189119</td>
#       <td id="T_6be19_row2_col5" class="data row2 col5" >0.096067</td>
#       <td id="T_6be19_row2_col6" class="data row2 col6" >0.280328</td>
#       <td id="T_6be19_row2_col7" class="data row2 col7" >0.198270</td>
#     </tr>
#     <tr>
#       <th id="T_6be19_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_6be19_row3_col0" class="data row3 col0" >-0.035322</td>
#       <td id="T_6be19_row3_col1" class="data row3 col1" >0.083081</td>
#       <td id="T_6be19_row3_col2" class="data row3 col2" >-0.308247</td>
#       <td id="T_6be19_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6be19_row3_col4" class="data row3 col4" >0.414838</td>
#       <td id="T_6be19_row3_col5" class="data row3 col5" >0.159651</td>
#       <td id="T_6be19_row3_col6" class="data row3 col6" >-0.253586</td>
#       <td id="T_6be19_row3_col7" class="data row3 col7" >-0.584471</td>
#     </tr>
#     <tr>
#       <th id="T_6be19_level0_row4" class="row_heading level0 row4" >parch</th>
#       <td id="T_6be19_row4_col0" class="data row4 col0" >0.081629</td>
#       <td id="T_6be19_row4_col1" class="data row4 col1" >0.018443</td>
#       <td id="T_6be19_row4_col2" class="data row4 col2" >-0.189119</td>
#       <td id="T_6be19_row4_col3" class="data row4 col3" >0.414838</td>
#       <td id="T_6be19_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_6be19_row4_col5" class="data row4 col5" >0.216225</td>
#       <td id="T_6be19_row4_col6" class="data row4 col6" >-0.349943</td>
#       <td id="T_6be19_row4_col7" class="data row4 col7" >-0.583398</td>
#     </tr>
#     <tr>
#       <th id="T_6be19_level0_row5" class="row_heading level0 row5" >fare</th>
#       <td id="T_6be19_row5_col0" class="data row5 col0" >0.257307</td>
#       <td id="T_6be19_row5_col1" class="data row5 col1" >-0.549500</td>
#       <td id="T_6be19_row5_col2" class="data row5 col2" >0.096067</td>
#       <td id="T_6be19_row5_col3" class="data row5 col3" >0.159651</td>
#       <td id="T_6be19_row5_col4" class="data row5 col4" >0.216225</td>
#       <td id="T_6be19_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_6be19_row5_col6" class="data row5 col6" >-0.182024</t
